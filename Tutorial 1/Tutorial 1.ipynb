# %% [markdown]
# # Tutorial 1

# %% [markdown]
# Thara Caba \
# April 5 2024

# %% [markdown]
# __a)__ Select galaxies and quasars with redshifts between 0.05 and 0.3 and signal-to-noise ratios greater than 35 near the Hβ line. Ensure that lines [O III] λ5007, Hβ λ4863, and Hγ λ4341 are present in emission and that the FWHM of Hβ is greater than 1000 km/s. For each selected spectrum, find the flux ratios of [OIII]/Hβ, Hβ/Hγ, and [O III]/Hγ, as well as the equivalent width and flux of Hβ, redshift, and extinction correction: E(B-V) of type SFD.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# from astropy.visualization import astropy_mpl_style
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
from astropy.table import Table

# %% [raw]
# SELECT
# s.plate, s.mjd, s.fiberid,
# s.z, g.subclass, g.e_bv_sfd,
# l.h_beta_flux, l.h_beta_eqw,
# (l.oiii_5007_flux/l.h_beta_flux) as oiii_h_beta_flux_ratio,
# (l.oiii_5007_flux/l.h_gamma_flux) as oiii_h_gamma_flux_ratio,
# (l.h_beta_flux/l.h_gamma_flux) as h_beta_h_gamma_flux_ratio
#
# FROM SpecObjAll AS s
# JOIN GalSpecInfo AS g ON s.specobjid = g.specobjid
# JOIN GalSpecLine AS l ON s.specobjid = l.specobjid
#
# WHERE
# (s.class = "QSO" OR s.class = "GALAXY")
# AND s.z BETWEEN 0.05 AND 0.3
# AND s.snmedian_g > 35
# AND l.h_gamma_eqw < 0
# AND l.h_beta_eqw < 0
# AND l.oiii_5007_eqw < 0
# AND l.h_gamma_flux <> 0
# AND l.h_beta_flux <> 0
# AND l.oiii_5007_flux <> 0
# AND l.sigma_balmer * 2.35 > 1000
#
# #In the SQL query provided, the operator "<>" is used to denote "not equal to". So, for example, the condition `l.h_gamma_flux <> 0` means that the value of `l.h_gamma_flux` should not be equal to zero for a record to be included in the result set.

# %% [markdown]
# __b)__ How many objects have you found? Which one from the conditions in WHERE is narrowing the results most severely?

# %%
df = pd.read_csv("/Users/tharacaba/Downloads/Skyserver_SQL4_10_2024 5_08_14 PM.csv")

# %%
df
# Out:
#                                                                                                                                                         #Table1
# plate mjd   fiberid z          subclass            e_bv_sfd    h_beta_flux h_beta_eqw oiii_h_beta_flux_ratio oiii_h_gamma_flux_ratio  h_beta_h_gamma_flux_ratio
# 304   51609 408     0.05209216 NaN                 0.03632782  116.535     -0.9988101 0.2246707              0.2314928                                 1.030365
# 1443  53055 358     0.2248686  STARBURST BROADLINE 0.02253275  4215.459    -21.6249   0.1243922              0.2960408                                 2.379898
# 1833  54561 567     0.05100999 NaN                 0.04346284  51.26057    -0.4272045 1.151556               1.346378                                  1.169181
# 2102  54115 521     0.06168568 NaN                 0.007514635 44.48927    -0.3869972 1.375886               1.818914                                  1.321995
# ...                                                                                                                                                         ...
# 2268  53682 451     0.05708254 NaN                 0.02708664  27.26945    -0.2428704 1.896562               2.57737                                   1.358969
# 2294  53733 87      0.0503883  BROADLINE           0.02452809  86.54166    -0.8824288 1.969931               218.5636                                  110.9499
# 2533  54585 612     0.1472984  AGN BROADLINE       0.05242494  873.853     -8.637259  0.6300117              1.070857                                  1.699741
# 2649  54212 215     0.1266571  BROADLINE           0.05069542  2140.768    -8.841555  1.036598               1.910092                                  1.842654
# 2669  54086 451     0.08929483 BROADLINE           0.4328821   9483.637    -21.56355  0.5544354              1.097662                                  1.979783
#
# [280 rows x 1 columns]

# %% [markdown]
# There are 279 objects.

# %% [raw]
# SELECT s.class, COUNT(*) as num_objects
#
# FROM SpecObjAll AS s
# JOIN GalSpecInfo AS g ON s.specobjid = g.specobjid
# JOIN GalSpecLine AS l ON s.specobjid = l.specobjid
#
# WHERE
# (s.class = "QSO" OR s.class = "GALAXY")
# AND s.snmedian_g > 35
# AND s.z BETWEEN 0.05 AND 0.3
# AND l.h_gamma_eqw < 0
# AND l.h_beta_eqw < 0
# AND l.oiii_5007_eqw < 0
# AND l.h_gamma_flux <> 0
# AND l.h_beta_flux <> 0
# AND l.oiii_5007_flux <> 0
# AND l.sigma_balmer * 2.35 > 1000
#
# GROUP BY s.class

# %% [markdown]
# Signal - to - noise is narrowing the results most severely.

# %% [markdown]
# __c)__ Find out if there is some of the Subclass AGN objects, with the same conditions under 1. Adopt your code to get result.

# %% [markdown]
# BROADLINE AGN

# %% [markdown]
# __d)__ Modify your solution under a) to include objects with redshift between 0.05 and 0.6. Using this modified solution and the list of objects (287-plate-mjd-fiber.txt) submit the SQL query via CrossID.

# %% [markdown]
# Using the options "Spectra", "Nearest prime spectrum", and "plate-MJD-fiberID":

# %% [raw]
# SELECT
# s.plate, s.mjd, s.fiberid,
# s.z, g.subclass, g.e_bv_sfd,
# l.h_beta_flux, l.h_beta_eqw,
# (l.oiii_5007_flux/l.h_beta_flux) as oiii_h_beta_flux_ratio,
# (l.oiii_5007_flux/l.h_gamma_flux) as oiii_h_gamma_flux_ratio,
# (l.h_beta_flux/l.h_gamma_flux) as h_beta_h_gamma_flux_ratio
#
# FROM SpecObjAll AS s
# JOIN GalSpecInfo AS g ON s.specobjid = g.specobjid
# JOIN GalSpecLine AS l ON s.specobjid = l.specobjid
#
# WHERE
# (s.class = "QSO" OR s.class = "GALAXY")
# AND s.z BETWEEN 0.05 AND 0.6
# AND s.snmedian_g > 35
# AND l.h_gamma_eqw < 0
# AND l.h_beta_eqw < 0
# AND l.oiii_5007_eqw < 0
# AND l.h_gamma_flux <> 0
# AND l.h_beta_flux <> 0
# AND l.oiii_5007_flux <> 0
# AND l.sigma_balmer * 2.35 > 1000

# %%
dfs = pd.read_csv("/Users/tharacaba/Downloads/Skyserver_CrossID4_18_2024 9_37_09 AM.csv")
dfs
# Out:
#                                                                                                                                             #Table1
# plate mjd   fiberid z         subclass  e_bv_sfd   h_beta_flux h_beta_eqw oiii_h_beta_flux_ratio oiii_h_gamma_flux_ratio  h_beta_h_gamma_flux_ratio
# 268   51633 235     0.595322  BROADLINE 0.03354528 677.1182    -9.859278  0.4154737              1.334858                                  3.212858
# 795   52378 528     0.5607508 BROADLINE 0.01193781 625.2177    -12.8672   0.4668604              0.8818083                                 1.888805
# 2645  54477 133     0.4930311 BROADLINE 0.02225282 937.1426    -14.06366  0.7994121              1.96633                                   2.459721
# 1754  53385 324     0.4343848 BROADLINE 0.03020268 1279.667    -15.685    0.646228               1.482974                                  2.294816
# 411   51817 381     0.5324706 BROADLINE 0.08810838 1313.903    -10.74767  0.4205669              1.289833                                  3.066892
# 1716  53827 350     0.5008188 BROADLINE 0.03326718 798.7177    -9.304626  0.9021373              1.71744                                   1.903746
# 1224  52765 379     0.5228383 BROADLINE 0.04002199 1333.446    -12.69335  0.3398808              0.9305261                                 2.737802
# 2347  53757 151     0.5113347 BROADLINE 0.02648882 1452.441    -16.70732  0.6893487              1.492386                                  2.164921
# 637   52174 259     0.5993487 BROADLINE 0.07477354 3992.194    -11.40223  0.2523734              0.5993569                                 2.374881
# 640   52178 513     0.4174148 BROADLINE 0.09496573 952.4866    -10.36639  0.3341854              0.5882106                                 1.760133
# 1843  53816 584     0.4980763 BROADLINE 0.01577194 557.34      -12.03965  0.4476209              1.072644                                  2.396323
# 2173  53874 354     0.4557629 BROADLINE 0.05542863 509.9599    -11.65119  0.6451375              1.609646                                  2.495043
# 856   52339 50      0.4271503 BROADLINE 0.03264315 2298.788    -19.17619  0.3084432              0.7104521                                 2.303349
# 897   52605 242     0.5136945 BROADLINE 0.03365997 1483.066    -16.58844  0.1680855              0.372335                                  2.215153
# 1810  53794 504     0.4596158 BROADLINE 0.02485074 1133.808    -14.90093  0.2570447              0.6261491                                 2.435954
# 2034  53466 230     0.5083145 BROADLINE 0.02323727 2134.027    -10.54055  0.3777993              0.9968096                                 2.638463
# 644   52173 413     0.5896417 BROADLINE 0.04080473 1035.502    -12.73695  0.5348418              1.2877                                    2.407628
# 767   52252 300     0.5540618 BROADLINE 0.01614243 934.5037    -8.894829  0.2535838              0.3946598                                 1.556329
# 2646  54479 204     0.4338264 BROADLINE 0.02289122 1557.825    -9.889492  0.1564952              0.2995124                                 1.913876
# 1694  53472 540     0.5119441 BROADLINE 0.0279867  1848.843    -16.54789  0.2110908              0.6078568                                 2.879598
# 465   51910 603     0.5496119 BROADLINE 0.0680838  799.0661    -11.59554  3.92246                7.667851                                  1.954858
# 1592  52990 18      0.5841894 BROADLINE 0.01962814 459.9291    -6.518604  0.7617553              1.164088                                  1.528165
# 656   52148 282     0.4236842 BROADLINE 0.02947504 1365.047    -12.31159  0.3461726              0.7257633                                 2.096536
# 564   52224 471     0.5112072 BROADLINE 0.03008878 2766.907    -16.15146  0.1912216              0.4443092                                 2.323531
# 976   52413 574     0.4689836 BROADLINE 0.03079161 1784.66     -20.90205  0.1869689              0.4386216                                 2.345961
# 555   52266 74      0.4688599 BROADLINE 0.02161665 552.9328    -10.00354  0.6370804              1.368653                                   2.14832
# 2520  54584 442     0.4358573 BROADLINE 0.05334958 178.4678    -11.22126  3.537334               6.07903                                   1.718534
# 408   51821 611     0.5689139 BROADLINE 0.03383083 927.9932    -11.62149  1.298259               2.755408                                  2.122388
# 1949  53433 472     0.5306148 BROADLINE 0.01484899 1219.554    -9.254515  2.822379               4.122338                                   1.46059
# 793   52370 549     0.513281  BROADLINE 0.01412164 481.7625    -8.881385  0.7883095              2.122867                                  2.692936
# 2526  54582 404     0.4583784 BROADLINE 0.05439631 965.0396    -11.94227  0.3373327              0.6804778                                 2.017231
# 1847  54176 630     0.4473778 BROADLINE 0.02485514 1699.505    -13.29521  0.4833947              1.049325                                  2.170741
# 561   52295 618     0.4208928 BROADLINE 0.01354015 625.7569    -8.85923   3.467889               6.112846                                    1.7627
# 1773  53112 301     0.4975437 BROADLINE 0.02385371 651.824     -6.771779  0.9197367              1.21164                                   1.317378
# 721   52228 454     0.502505  BROADLINE 0.05165878 574.8325    -20.61713  0.4051845              0.9839695                                 2.428448
# 939   52636 172     0.4219211 BROADLINE 0.01403132 575.824     -5.977588  0.5175255              0.8794833                                 1.699401
# 2512  53877 582     0.5215923 BROADLINE 0.04497579 673.3281    -6.979514  0.4139671              0.9204111                                 2.223392
# 607   52368 581     0.5525806 BROADLINE 0.01419172 567.0939    -11.73849  0.4498428              1.061532                                  2.359785
# 554   52000 553     0.4736708 BROADLINE 0.02523354 961.0248    -8.415974  1.069571               1.917614                                  1.792881
# 464   51908 576     0.5702274 BROADLINE 0.0965671  367.0603    -3.915135  0.4052001              0.4592269                                 1.133334
# 2425  54139 442     0.5659922 BROADLINE 0.04197626 422.1902    -7.778267  1.199032               1.931223                                  1.610652
# 329   52056 577     0.4580766 BROADLINE 0.02008798 1135.089    -15.52481  0.721276               1.458682                                  2.022363
# 1844  54138 112     0.5256413 BROADLINE 0.02177914 717.105     -6.350803  0.5879771              1.071625                                  1.822562
# 498   51984 104     0.4614837 BROADLINE 0.01426796 462.6565    -10.74795  0.5001677              1.173522                                  2.346257
# 2606  54154 614     0.552017  BROADLINE 0.02188222 1450.117    -9.709053  0.2476668              0.4893284                                 1.975753
# 1791  54266 46      0.4389866 BROADLINE 0.02399247 1027.594    -17.74196  0.3758007              0.8569891                                 2.280435
# 402   51793 479     0.5524943 BROADLINE 0.03973217 1318.962    -11.35889  0.307347               0.7138805                                 2.322718

# %% [markdown]
# __e)__ Check the spectra of found objects, download some of them using wget.

# %% [raw]
# wget -i https://data.sdss.org/sas/dr18/spectro/sdss/redux/26/spectra/lite/0268/spec-0268-51633-0235.fits

# %% [markdown]
# __d)__ BONUS: read downloaded fits files and plot the spectra using Python.

# %%
obj_1 = fits.open('/Users/tharacaba/Desktop/AGN/spec-0268-51633-0235.fits', memmap=True)

# %%
print(obj_1[1].columns)
# Out:
# ColDefs(
#     name = 'flux'; format = 'E'
#     name = 'loglam'; format = 'E'
#     name = 'ivar'; format = 'E'
#     name = 'and_mask'; format = 'J'
#     name = 'or_mask'; format = 'J'
#     name = 'wdisp'; format = 'E'
#     name = 'sky'; format = 'E'
#     name = 'model'; format = 'E'
# )

# %%
obj_1_data = Table(obj_1[1].data)
obj_1_data
# Out:
# <Table length=3832>
#    flux    loglam     ivar    and_mask or_mask   wdisp       sky      model
#  float32  float32   float32    int32    int32   float32    float32   float32
# --------- ------- ----------- -------- ------- ---------- --------- ----------
# 118.85568    3.58 0.025620818        0       0  1.3487778 10.223456  116.23333
# 115.65326  3.5801 0.028720735        0       0  1.3482839  9.897737  115.39884
# 106.71307  3.5802 0.031155253        0       0  1.3477901  9.624965   115.2619
# 107.15258  3.5803 0.031942006        0       0  1.3472986 9.3489895  113.99698
# 105.32813  3.5804 0.032686844        0       0  1.3468072  9.063609  112.87552
# 108.93706  3.5805  0.03226811        0       0  1.3463138  8.771913 113.042656
#       ...     ...         ...      ...     ...        ...       ...        ...
# 21.485104  3.9625   0.6130533        0       0  0.9355925  4.129818  22.601961
# 22.708017  3.9626   0.5525634        0       0 0.93563443  4.586115  22.503191
# 19.129177  3.9627  0.55310804        0       0  0.9356774 4.9334745  22.757278
# 23.327608  3.9628   0.5504477        0       0   0.935719  4.783296  22.977318
# 24.677168  3.9629   0.5790535        0       0 0.93575996   4.60223  22.943377
# 22.164875   3.963   0.6273204        0       0  0.9358017  4.616978  22.853764
# 22.103271  3.9631   0.6283162        0       0  0.9358426   4.75673     22.937

# %%
plt.figure(figsize=(12, 5))
plt.plot(obj_1_data['loglam'], obj_1_data['flux'], c='darkmagenta')

plt.xlabel(r'Wavelength (log scale) [Ang]')
plt.ylabel(r'Flux [$10^{-7}$ erg / s / cm$^2$ / Ang]')

plt.title('Object SDSS J210001.24-071136.3 (0637-52174-0259)')

# plt.savefig('spectra_plots/spectra_obj_1.pdf')

plt.show()
